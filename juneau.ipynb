# %% [markdown]
# # Juneau County, WI (Necedah)

# %%
# Import python libraries
import getpass
import json
import os
import pathlib
from glob import glob

# Library to work with tabular data
import pandas as pd

# Library to work with vector data
import geopandas as gpd

import earthpy.appeears as eaapp
import hvplot.pandas 
import hvplot.xarray
import rioxarray as rxr
import xarray as xr # uses numpy
import matplotlib.pyplot as plt
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
juneau_dir = os.path.join(pathlib.Path.home(), 'juneau-data')
# Make the data directory
os.makedirs(juneau_dir, exist_ok=True)

juneau_dir
# Out:
# '/home/jovyan/juneau-data'

# %%
wi_counties_url = 'https://www2.census.gov/geo/tiger/TIGER2018/COUSUB/tl_2018_55_cousub.zip'
wi_counties_gdf = gpd.read_file(wi_counties_url)
wi_counties_gdf
# Out:
#      STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID         NAME  \
# 0         55      043    49350  01583655  5504349350       Marion
# 1         55      053    00350  01582656  5505300350        Adams
# 2         55      053    79150  01584268  5505379150       Taylor
# 3         55      043    52150  01583720  5504352150    Millville
# 4         55      043    84075  01584368  5504384075  Watterstown
# ...      ...      ...      ...       ...         ...          ...
# 1921      55      005    05650  01582772  5500505650    Bear Lake
# 1922      55      005    12250  01582910  5500512250      Cameron
# 1923      55      005    13500  01582939  5500513500   Cedar Lake
# 1924      55      005    14325  01582951  5500514325       Chetek
# 1925      55      005    14350  01582952  5500514350       Chetek
#
#               NAMELSAD LSAD CLASSFP  MTFCC  CNECTAFP  NECTAFP  NCTADVFP  \
# 0          Marion town   43      T1  G4040       NaN      NaN       NaN
# ...

# %%
juneau = wi_counties_gdf[wi_counties_gdf["NAME"] == "Juneau"]
juneau
# Out:
#     STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID    NAME     NAMELSAD LSAD  \
# 621      55      027    38675  01583462  5502738675  Juneau  Juneau city   25
#
#     CLASSFP  MTFCC  CNECTAFP  NECTAFP  NCTADVFP FUNCSTAT    ALAND  AWATER  \
# 621      C5  G4040       NaN      NaN       NaN        F  4271479    3438
#
#         INTPTLAT      INTPTLON  \
# 621  +43.4029044  -088.7032559
#
#                                               geometry
# 621  MULTIPOLYGON (((-88.70440 43.37927, -88.70430 ...

# %%
# Initialize AppeearsDownloader for MODIS NDVI data
ndvi_downloader = eaapp.AppeearsDownloader(
    download_key='juneau-ndvi',
    ea_dir=juneau_dir,
    product='MOD13Q1.061',
    layer='_250m_16_days_NDVI',
    start_date="07-01",
    end_date="07-31",
    recurring=True,
    year_range=[2015, 2020],
    polygon=juneau
)

ndvi_downloader.download_files(cache=True)
